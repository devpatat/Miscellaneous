# %%
import xlwings as xw
import pandas as pd

# %%
wb= xw.Book('Testing 2.xlsx')

# %%
sht = wb.sheets['Input Sheet (Business Owner)']

# %%
sht_test = wb.sheets['Testing (BO)']

# %%
ip = []
var =[]

# %%
for i in range(5,58):
    ip.append(sht_test['E'+str(i)].value)
    var.append(sht_test['D'+str(i)].value)

# %%
import pandas as pd
print("Input is as follows Scenerio 1: ")
df = pd.DataFrame(list(zip(var, ip)), 
               columns =['Input', 'Value'],index=None) 
df.style.hide_index()
# Out:
# Input is as follows Scenerio 1:
# <style  type="text/css" >
# </style><table id="T_9aec2afe_3780_11ea_bf1b_48ba4e1bf331" ><thead>    <tr>        <th class="col_heading level0 col0" >Input</th>        <th class="col_heading level0 col1" >Value</th>    </tr></thead><tbody>
#                 <tr>
#                                 <td id="T_9aec2afe_3780_11ea_bf1b_48ba4e1bf331row0_col0" class="data row0 col0" >Age</td>
#                         <td id="T_9aec2afe_3780_11ea_bf1b_48ba4e1bf331row0_col1" class="data row0 col1" >18 to 30</td>
#             </tr>
#             <tr>
#                                 <td id="T_9aec2afe_3780_11ea_bf1b_48ba4e1bf331row1_col0" class="data row1 col0" >Gender</td>
#                         <td id="T_9aec2afe_3780_11ea_bf1b_48ba4e1bf331row1_col1" class="data row1 col1" >Male</td>
#             </tr>
#             <tr>
#                                 <td id="T_9aec2afe_3780_11ea_bf1b_48ba4e1bf331row2_col0" class="data row2 col0" >Marital Status</td>
# ...

# %%
#append input to Input Sheet
for i in range(7,60):
    sht['D'+str(i)].value = ip[i-7]

# %%
sht_out = wb.sheets['Output Sheet (Business Owner)']

# %%
var_res = ["Eligibility Criteria","Loan Status","Interest Rate","Loan Amount"]
val_res = []
val_res.append(sht_out['D85'].value)
val_res.append(sht_out['D91'].value)
val_res.append(str((sht_out['D92'].value)*100)+"%")
val_res.append(sht_out['D90'].value)

# %%
print("Output for Scenario 1 is as follows : ")
df = pd.DataFrame(list(zip(var_res, val_res)), 
               columns =['Output', 'Value'],index=None) 
df.style.hide_index()
# Out:
# Output for Scenario 1 is as follows :
# <style  type="text/css" >
# </style><table id="T_9caea7e6_3780_11ea_86b7_48ba4e1bf331" ><thead>    <tr>        <th class="col_heading level0 col0" >Output</th>        <th class="col_heading level0 col1" >Value</th>    </tr></thead><tbody>
#                 <tr>
#                                 <td id="T_9caea7e6_3780_11ea_86b7_48ba4e1bf331row0_col0" class="data row0 col0" >Eligibility Criteria</td>
#                         <td id="T_9caea7e6_3780_11ea_86b7_48ba4e1bf331row0_col1" class="data row0 col1" >ELIGIBLE</td>
#             </tr>
#             <tr>
#                                 <td id="T_9caea7e6_3780_11ea_86b7_48ba4e1bf331row1_col0" class="data row1 col0" >Loan Status</td>
#                         <td id="T_9caea7e6_3780_11ea_86b7_48ba4e1bf331row1_col1" class="data row1 col1" >APPROVED</td>
#             </tr>
#             <tr>
# ...

# %%
ip=[]
for i in range(5,58):
    ip.append(sht_test['F'+str(i)].value)

# %%
print("Input is as follows Scenerio 2: ")
df = pd.DataFrame(list(zip(var, ip)), 
               columns =['Input', 'Value'],index=None) 
df.style.hide_index()
# Out:
# Input is as follows Scenerio 2:
# <style  type="text/css" >
# </style><table id="T_9ce82cda_3780_11ea_a067_48ba4e1bf331" ><thead>    <tr>        <th class="col_heading level0 col0" >Input</th>        <th class="col_heading level0 col1" >Value</th>    </tr></thead><tbody>
#                 <tr>
#                                 <td id="T_9ce82cda_3780_11ea_a067_48ba4e1bf331row0_col0" class="data row0 col0" >Age</td>
#                         <td id="T_9ce82cda_3780_11ea_a067_48ba4e1bf331row0_col1" class="data row0 col1" >40 to 50</td>
#             </tr>
#             <tr>
#                                 <td id="T_9ce82cda_3780_11ea_a067_48ba4e1bf331row1_col0" class="data row1 col0" >Gender</td>
#                         <td id="T_9ce82cda_3780_11ea_a067_48ba4e1bf331row1_col1" class="data row1 col1" >Female</td>
#             </tr>
#             <tr>
# ...

# %%
#append input to Input Sheet
for i in range(7,59):
    sht['D'+str(i)].value = ip[i-7]

# %%
val_res = []
val_res.append(sht_out['D85'].value)
val_res.append(sht_out['D91'].value)
val_res.append(str((sht_out['D92'].value)*100)+"%")
val_res.append(sht_out['D90'].value)

# %%
print("Output for scenario 2 is as follows : ")
df = pd.DataFrame(list(zip(var_res, val_res)), 
               columns =['Output', 'Value'],index=None) 
df.style.hide_index()
# Out:
# Output for scenario 2 is as follows :
# <style  type="text/css" >
# </style><table id="T_9d9dba9a_3780_11ea_92a2_48ba4e1bf331" ><thead>    <tr>        <th class="col_heading level0 col0" >Output</th>        <th class="col_heading level0 col1" >Value</th>    </tr></thead><tbody>
#                 <tr>
#                                 <td id="T_9d9dba9a_3780_11ea_92a2_48ba4e1bf331row0_col0" class="data row0 col0" >Eligibility Criteria</td>
#                         <td id="T_9d9dba9a_3780_11ea_92a2_48ba4e1bf331row0_col1" class="data row0 col1" >ELIGIBLE</td>
#             </tr>
#             <tr>
#                                 <td id="T_9d9dba9a_3780_11ea_92a2_48ba4e1bf331row1_col0" class="data row1 col0" >Loan Status</td>
#                         <td id="T_9d9dba9a_3780_11ea_92a2_48ba4e1bf331row1_col1" class="data row1 col1" >APPROVED</td>
#             </tr>
#             <tr>
# ...

# %%
ip=[]
for i in range(5,58):
    ip.append(sht_test['G'+str(i)].value)

print("Input is as follows Scenerio 3: ")
df = pd.DataFrame(list(zip(var, ip)), 
               columns =['Input', 'Value'],index=None) 
df.style.hide_index()
# Out:
# Input is as follows Scenerio 3:
# <style  type="text/css" >
# </style><table id="T_9de0625a_3780_11ea_8c21_48ba4e1bf331" ><thead>    <tr>        <th class="col_heading level0 col0" >Input</th>        <th class="col_heading level0 col1" >Value</th>    </tr></thead><tbody>
#                 <tr>
#                                 <td id="T_9de0625a_3780_11ea_8c21_48ba4e1bf331row0_col0" class="data row0 col0" >Age</td>
#                         <td id="T_9de0625a_3780_11ea_8c21_48ba4e1bf331row0_col1" class="data row0 col1" >50 to 65</td>
#             </tr>
#             <tr>
#                                 <td id="T_9de0625a_3780_11ea_8c21_48ba4e1bf331row1_col0" class="data row1 col0" >Gender</td>
#                         <td id="T_9de0625a_3780_11ea_8c21_48ba4e1bf331row1_col1" class="data row1 col1" >Male</td>
#             </tr>
#             <tr>
#                                 <td id="T_9de0625a_3780_11ea_8c21_48ba4e1bf331row2_col0" class="data row2 col0" >Marital Status</td>
# ...

# %%
#append input to Input Sheet
for i in range(7,60):
    sht['D'+str(i)].value = ip[i-7]
val_res = []
val_res.append(sht_out['D85'].value)
val_res.append(sht_out['D91'].value)
val_res.append(str((sht_out['D92'].value)*100)+"%")
val_res.append(sht_out['D90'].value)
print("Output for scenario 3 is as follows : ")
df = pd.DataFrame(list(zip(var_res, val_res)), 
               columns =['Output', 'Value'],index=None) 
df.style.hide_index()
# Out:
# Output for scenario 3 is as follows :
# <style  type="text/css" >
# </style><table id="T_9f2fcb40_3780_11ea_918a_48ba4e1bf331" ><thead>    <tr>        <th class="col_heading level0 col0" >Output</th>        <th class="col_heading level0 col1" >Value</th>    </tr></thead><tbody>
#                 <tr>
#                                 <td id="T_9f2fcb40_3780_11ea_918a_48ba4e1bf331row0_col0" class="data row0 col0" >Eligibility Criteria</td>
#                         <td id="T_9f2fcb40_3780_11ea_918a_48ba4e1bf331row0_col1" class="data row0 col1" >ELIGIBLE</td>
#             </tr>
#             <tr>
#                                 <td id="T_9f2fcb40_3780_11ea_918a_48ba4e1bf331row1_col0" class="data row1 col0" >Loan Status</td>
#                         <td id="T_9f2fcb40_3780_11ea_918a_48ba4e1bf331row1_col1" class="data row1 col1" >APPROVED</td>
#             </tr>
#             <tr>
# ...

# %%
ip=[]
for i in range(5,58):
    ip.append(sht_test['H'+str(i)].value)

print("Input is as follows Scenerio 4: ")
df = pd.DataFrame(list(zip(var, ip)), 
               columns =['Input', 'Value'],index=None) 
df.style.hide_index()
# Out:
# Input is as follows Scenerio 4:
# <style  type="text/css" >
# </style><table id="T_9f53dc5a_3780_11ea_94a5_48ba4e1bf331" ><thead>    <tr>        <th class="col_heading level0 col0" >Input</th>        <th class="col_heading level0 col1" >Value</th>    </tr></thead><tbody>
#                 <tr>
#                                 <td id="T_9f53dc5a_3780_11ea_94a5_48ba4e1bf331row0_col0" class="data row0 col0" >Age</td>
#                         <td id="T_9f53dc5a_3780_11ea_94a5_48ba4e1bf331row0_col1" class="data row0 col1" >30 to 40</td>
#             </tr>
#             <tr>
#                                 <td id="T_9f53dc5a_3780_11ea_94a5_48ba4e1bf331row1_col0" class="data row1 col0" >Gender</td>
#                         <td id="T_9f53dc5a_3780_11ea_94a5_48ba4e1bf331row1_col1" class="data row1 col1" >Female</td>
#             </tr>
#             <tr>
# ...

# %%
#append input to Input Sheet
for i in range(7,60):
    sht['D'+str(i)].value = ip[i-7]
val_res = []
val_res.append(sht_out['D85'].value)
val_res.append(sht_out['D91'].value)
val_res.append(str((sht_out['D92'].value)*100)+"%")
val_res.append(sht_out['D90'].value)
print("Output for scenario 4 is as follows : ")
df = pd.DataFrame(list(zip(var_res, val_res)), 
               columns =['Output', 'Value'],index=None) 
df.style.hide_index()
# Out:
# Output for scenario 4 is as follows :
# <style  type="text/css" >
# </style><table id="T_9fd22cfa_3780_11ea_83f1_48ba4e1bf331" ><thead>    <tr>        <th class="col_heading level0 col0" >Output</th>        <th class="col_heading level0 col1" >Value</th>    </tr></thead><tbody>
#                 <tr>
#                                 <td id="T_9fd22cfa_3780_11ea_83f1_48ba4e1bf331row0_col0" class="data row0 col0" >Eligibility Criteria</td>
#                         <td id="T_9fd22cfa_3780_11ea_83f1_48ba4e1bf331row0_col1" class="data row0 col1" >ELIGIBLE</td>
#             </tr>
#             <tr>
#                                 <td id="T_9fd22cfa_3780_11ea_83f1_48ba4e1bf331row1_col0" class="data row1 col0" >Loan Status</td>
#                         <td id="T_9fd22cfa_3780_11ea_83f1_48ba4e1bf331row1_col1" class="data row1 col1" >APPROVED</td>
#             </tr>
#             <tr>
# ...

# %%
ip=[]
for i in range(5,58):
    ip.append(sht_test['I'+str(i)].value)

print("Input is as follows Scenerio 5: ")
df = pd.DataFrame(list(zip(var, ip)) ,columns =['Input', 'Value'],index=None) 
df.style.hide_index()
# Out:
# Input is as follows Scenerio 5:
# <style  type="text/css" >
# </style><table id="T_9ffa58c8_3780_11ea_9ba9_48ba4e1bf331" ><thead>    <tr>        <th class="col_heading level0 col0" >Input</th>        <th class="col_heading level0 col1" >Value</th>    </tr></thead><tbody>
#                 <tr>
#                                 <td id="T_9ffa58c8_3780_11ea_9ba9_48ba4e1bf331row0_col0" class="data row0 col0" >Age</td>
#                         <td id="T_9ffa58c8_3780_11ea_9ba9_48ba4e1bf331row0_col1" class="data row0 col1" >18 to 30</td>
#             </tr>
#             <tr>
#                                 <td id="T_9ffa58c8_3780_11ea_9ba9_48ba4e1bf331row1_col0" class="data row1 col0" >Gender</td>
#                         <td id="T_9ffa58c8_3780_11ea_9ba9_48ba4e1bf331row1_col1" class="data row1 col1" >Male</td>
#             </tr>
#             <tr>
#                                 <td id="T_9ffa58c8_3780_11ea_9ba9_48ba4e1bf331row2_col0" class="data row2 col0" >Marital Status</td>
# ...

# %%
#append input to Input Sheet
for i in range(7,60):
    sht['D'+str(i)].value = ip[i-7]
val_res = []
val_res.append(sht_out['D85'].value)
val_res.append(sht_out['D91'].value)
val_res.append(str((sht_out['D92'].value)*100)+"%")
val_res.append(sht_out['D90'].value)
print("Output for scenario 5 is as follows : ")
df = pd.DataFrame(list(zip(var_res, val_res)),  columns =['Output', 'Value'],index=None) 
df.style.hide_index()
# Out:
# Output for scenario 5 is as follows :
# <style  type="text/css" >
# </style><table id="T_a08baefa_3780_11ea_93c4_48ba4e1bf331" ><thead>    <tr>        <th class="col_heading level0 col0" >Output</th>        <th class="col_heading level0 col1" >Value</th>    </tr></thead><tbody>
#                 <tr>
#                                 <td id="T_a08baefa_3780_11ea_93c4_48ba4e1bf331row0_col0" class="data row0 col0" >Eligibility Criteria</td>
#                         <td id="T_a08baefa_3780_11ea_93c4_48ba4e1bf331row0_col1" class="data row0 col1" >ELIGIBLE</td>
#             </tr>
#             <tr>
#                                 <td id="T_a08baefa_3780_11ea_93c4_48ba4e1bf331row1_col0" class="data row1 col0" >Loan Status</td>
#                         <td id="T_a08baefa_3780_11ea_93c4_48ba4e1bf331row1_col1" class="data row1 col1" >APPROVED</td>
#             </tr>
#             <tr>
# ...
