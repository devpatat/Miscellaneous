# %%
import pandas as pd

# %%
data = pd.read_csv("data.csv")

# %%
data.head()
# Out:
#       id  age  workclass     education  education_num      marital_status  \
# 0  12106   32    Private       HS-grad              9            Divorced
# 1  28951   43  State-gov  Some-college             10            Divorced
# 2  24570   35    Private       HS-grad              9  Married-civ-spouse
# 3  16358   31    Private           NaN             14       Never-married
# 4   9375   64    Private  Some-college             10  Married-civ-spouse
#
#         occupation    relationship    race     sex  capital_gain  \
# 0     Adm-clerical  Other-relative  W hite  Female             0
# 1     Adm-clerical       Unmarried  W hite  Female             0
# 2  Exec-managerial            Wife   White  Female             0
# 3   Prof-specialty   Not-in-family   Black    Male             0
# 4  Exec-managerial            Wife   White  Female         10566
#
#    capital_loss  hours_per_week native_country over_50k
# 0             0              40  United-States    <=50K
# 1             0              40  United-States    <=50K
# 2             0              40  United-States     >50K
# 3             0              40  United-States    <=50K
# 4             0              35  United-States    <=50K

# %% [markdown]
# ID Column: id,
#
# Target: over_50k

# %% [markdown]
# **Handle missing values: We'll search for the columns that has missing values**

# %%
data.isna().sum()
# Out:
# id                   0
# age                  0
# workclass            0
# education         3024
# education_num        0
# marital_status       0
# occupation           0
# relationship         0
# race                 0
# sex                  0
# capital_gain         0
# capital_loss         0
# hours_per_week       0
# native_country       0
# over_50k          3271
# dtype: int64

# %% [markdown]
# **Columnns to drop: ID(no use), Education(as it has missing values) but the corresponding columnn "Education_num" doesn't have any and we see clear mapping between those two.**

# %%
data.drop(["id", "education"], axis = 1, inplace = True)

# %%
data
# Out:
#        age  workclass  education_num      marital_status       occupation  \
# 0       32    Private              9            Divorced     Adm-clerical
# 1       43  State-gov             10            Divorced     Adm-clerical
# 2       35    Private              9  Married-civ-spouse  Exec-managerial
# 3       31    Private             14       Never-married   Prof-specialty
# 4       64    Private             10  Married-civ-spouse  Exec-managerial
# ...    ...        ...            ...                 ...              ...
# 30200   56    Private             13  Married-civ-spouse  Exec-managerial
# 30201   58    Private              6  Married-civ-spouse    Other-service
# 30202   39    Private             10  Married-civ-spouse  Exec-managerial
# 30203   40  State-gov             15  Married-civ-spouse   Prof-specialty
# 30204   -1    Private             11       Never-married     Adm-clerical
#
#          relationship    race     sex  capital_gain  capital_loss  \
# 0      Other-relative  W hite  Female             0             0
# 1           Unmarried  W hite  Female             0             0
# 2                Wife   White  Female             0             0
# 3       Not-in-family   Black    Male             0             0
# 4                Wife   White  Female         10566             0
# ...               ...     ...     ...           ...           ...
# 30200         Husband   White    Male          4508             0
# 30201            Wife   White  Female             0             0
# 30202         Husband   White    Male             0             0
# 30203         Husband   White    Male             0             0
# 30204       Own-child   Black  Female             0             0
#
#        hours_per_week native_country over_50k
# 0                  40  United-States    <=50K
# 1                  40  United-States    <=50K
# 2                  40  United-States     >50K
# 3                  40  United-States    <=50K
# 4                  35  United-States    <=50K
# ...               ...            ...      ...
# 30200              40  United-States    <=50K
# 30201               8  United-States    <=50K
# 30202              40  United-States     >50K
# 30203              38  United-States      NaN
# 30204              40  United-States    <=50K
#
# [30205 rows x 13 columns]

# %% [markdown]
# **Now, we'll encode all string into numerical values as models don't understand strings**

# %%
from sklearn import preprocessing 
  
# label_encoder object knows how to understand word labels. 
label_encoder = preprocessing.LabelEncoder()

# %%
data['workclass']= label_encoder.fit_transform(data['workclass']) 
data["marital_status"]= label_encoder.fit_transform(data["marital_status"]) 
data["occupation"]= label_encoder.fit_transform(data["occupation"]) 
data["relationship"]= label_encoder.fit_transform(data["relationship"]) 
data["sex"]= label_encoder.fit_transform(data["sex"]) 
data["race"]= label_encoder.fit_transform(data["race"]) 
data["native_country"]= label_encoder.fit_transform(data["native_country"])

# %%
data.head()
# Out:
#    age  workclass  education_num  marital_status  occupation  relationship  \
# 0   32          4              9               0           1             2
# 1   43          7             10               0           1             4
# 2   35          4              9               2           4             5
# 3   31          4             14               4          10             1
# 4   64          4             10               2           4             5
#
#    race  sex  capital_gain  capital_loss  hours_per_week  native_country  \
# 0     4    0             0             0              40              39
# 1     4    0             0             0              40              39
# 2     5    0             0             0              40              39
# 3     2    1             0             0              40              39
# 4     5    0         10566             0              35              39
#
#   over_50k
# 0    <=50K
# 1    <=50K
# 2     >50K
# 3    <=50K
# 4    <=50K

# %% [markdown]
# **So we'll divide data into training and test dataset:**
# 1. Training set: Rows that have a target label for "over_50k", we'll train the model on this data and check accuracy.
# 2. Test set: Rows that does not have a target label for "over_50k", we'll make predictions on this dataset.

# %%
train = data[data["over_50k"].notnull()]
test = data[data["over_50k"].isna()]

# %%
test.drop(["over_50k"], axis = 1, inplace = True)
# Out:
# C:\Users\Dev\AppData\Roaming\Python\Python36\site-packages\pandas\core\frame.py:4117: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %% [markdown]
# **Again, we need to encode the target but this time we'll use replace method:**

# %%
train["over_50k"].unique()
# Out:
# array(['<=50K', '>50K'], dtype=object)

# %%
cleanup_nums = {"over_50k": {"<=50K": 0, ">50K":1 }}

# %%
train.replace(cleanup_nums, inplace=True)
train.head()
# Out:
# C:\Users\Dev\AppData\Roaming\Python\Python36\site-packages\pandas\core\generic.py:6702: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   regex=regex,
#    age  workclass  education_num  marital_status  occupation  relationship  \
# 0   32          4              9               0           1             2
# 1   43          7             10               0           1             4
# 2   35          4              9               2           4             5
# 3   31          4             14               4          10             1
# 4   64          4             10               2           4             5
#
#    race  sex  capital_gain  capital_loss  hours_per_week  native_country  \
# 0     4    0             0             0              40              39
# 1     4    0             0             0              40              39
# 2     5    0             0             0              40              39
# 3     2    1             0             0              40              39
# 4     5    0         10566             0              35              39
#
#    over_50k
# 0         0
# 1         0
# 2         1
# 3         0
# 4         0

# %% [markdown]
# **This is our final training set on which we'll train the model. We'll also save a copy of this.**

# %%
train.to_csv("training_data.csv",index=0)

# %% [markdown]
# **We'll also save a copy for testing data.**

# %%
test.to_csv("test.csv",index=0)

# %%
y = train.over_50k
X = train.drop('over_50k',axis=1)

# %% [markdown]
# **Here comes, Model fitting , we'll split the training set in train and test, here train set will be used for training and test will be used for checking accuracy**

# %%
from sklearn.linear_model import LogisticRegression
from sklearn import metrics
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=0)
logreg = LogisticRegression()
logreg.fit(X_train, y_train)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
y_pred = logreg.predict(X_test)
print('Accuracy of logistic regression classifier on test set: {:.2f}'.format(logreg.score(X_test, y_test)))
# Out:
# Accuracy of logistic regression classifier on test set: 0.86

# %% [markdown]
# **To make predictions using this model, we'll use the test data that had no target value initially**

# %%
pred = logreg.predict(test)

# %%
test['Predictions'] = pred
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %% [markdown]
# **We'll replace the 0,1 class back to its original label**

# %%
reverse_nums = {"Predictions": {0:"<=50K", 1:">50K" }}

# %%
test.replace(reverse_nums, inplace=True)
test.head()
# Out:
# C:\Users\Dev\AppData\Roaming\Python\Python36\site-packages\pandas\core\generic.py:6702: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   regex=regex,
#     age  workclass  education_num  marital_status  occupation  relationship  \
# 33   34          1             13               2          11             0
# 60   41          4             13               2           4             0
# 70   31          0             13               2           0             5
# 71   56          4             13               2          10             0
# 79   52          6             13               2           4             0
#
#     race  sex  capital_gain  capital_loss  hours_per_week  native_country  \
# 33     5    1             0          1902              48              39
# 60     5    1             0             0              50              39
# 70     5    0             0             0              25              39
# 71     5    1             0             0              40              39
# 79     5    1             0             0              50              39
#
#    Predictions
# 33       <=50K
# 60       <=50K
# 70       <=50K
# 71       <=50K
# 79       <=50K

# %%
test.to_csv("Predictions.csv",index=0)
